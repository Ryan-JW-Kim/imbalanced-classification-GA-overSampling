# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score, recall_score, precision_score
from scipy.stats import ranksums

from pymoo.util.nds.non_dominated_sorting import NonDominatedSorting
from pymoo.operators.mutation.bitflip import BitflipMutation
from pymoo.operators.sampling.rnd import Sampling
from pymoo.operators.crossover.hux import HUX
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.core.problem import Problem
from pymoo.optimize import minimize

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn as nn
import torch

from joblib import Parallel, delayed
from datetime import datetime
import pandas as pd
import numpy as np
import pickle
import os
from scipy.stats.mstats import gmean

import wandb

with open('data.pickle', 'rb') as fh:
	data_mapper = pickle.load(fh)

# %%
from imblearn.over_sampling import (
    SMOTE,
    ADASYN,
    BorderlineSMOTE,
)
from imblearn.combine import (
    SMOTETomek,
    SMOTEENN
)

# %%
class AUC_Filter(Problem):
	population_size = 100
	n_neighbours = 5
	log_every = 5
	def __init__(self, X_train, y_train, X_val, y_val, X_test, Y_test, logger=None):
		
		self.generation_number = 0

		self.X_train = X_train
		self.y_train = y_train
		self.X_val = X_val
		self.y_val = y_val
		self.X_TEST = X_test
		self.Y_TEST = Y_test
		self.logger = logger

		self.training_data = X_train
		self.n_instances = X_train.shape[0]
		
		super().__init__(
			n_var=self.n_instances,
			n_obj=2,               
			n_constr=0,            
			xl=0,                  
			xu=1,                  
			type_var=np.bool_,     
		)

	def _evaluate(self, x, out, *args, **kwargs):
		
		values = []
		num_samples = []
		for instance in x:
			inverse_AUC = 1
			if np.sum(instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(
					n_neighbors=AUC_Optimizer.n_neighbours
				)
				model.fit(
					self.X_train[instance], 
					self.y_train[instance]
				)

				y_pred = model.predict(self.X_val)
				inverse_AUC = 1 - roc_auc_score(self.y_val, y_pred)
			
			num_samples.append(np.sum(instance))
			values.append(inverse_AUC)
		F = np.column_stack([values, num_samples])
		self.generation_number += 1
		
		if self.logger is not None and self.generation_number % AUC_Optimizer.log_every == 0:
			validation_aucs = []
			test_aucs = []
			pareto_indices = NonDominatedSorting().do(F, only_non_dominated_front=True)
			
			for idx in pareto_indices:
				instance = x[idx]

				if np.sum(instance) >= AUC_Optimizer.n_neighbours:
					model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
					model.fit(
						self.X_train[instance], 
						self.y_train[instance]
					)
					y_pred = model.predict(self.X_val)
					validation_aucs.append(roc_auc_score(self.y_val, y_pred))
					y_pred = model.predict(self.X_TEST)
					test_aucs.append(roc_auc_score(self.Y_TEST, y_pred))
				else:
					validation_aucs.append(0)
					test_aucs.append(0)
					
			validation_idx = np.argmax(validation_aucs)
			test_idx = np.argmax(test_aucs)	
			x_ideal_validation_instance = self.X_train[x[pareto_indices[validation_idx]]]
			y_ideal_validation_instance = self.y_train[x[pareto_indices[validation_idx]]]
			x_ideal_test_instance = self.X_train[x[pareto_indices[test_idx]]]
			y_ideal_test_instance = self.y_train[x[pareto_indices[test_idx]]]

			if len(x_ideal_validation_instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(
					x_ideal_validation_instance, 
					y_ideal_validation_instance
				)

				y_pred = model.predict(self.X_val)
				optimized_validation_auc = roc_auc_score(self.y_val, y_pred)
				
				y_pred = model.predict(self.X_TEST)
				optimized_test_auc = roc_auc_score(self.Y_TEST, y_pred)
			else:
				optimized_validation_auc = 0
				optimized_test_auc = 0

			# Calculate metrics using ideal instance w.r.t test AUC
			if len(x_ideal_test_instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(
					x_ideal_test_instance, 
					y_ideal_test_instance
				)
				
				y_pred = model.predict(self.X_TEST)
				ideal_test_auc = roc_auc_score(self.Y_TEST, y_pred)
			else:
				ideal_test_auc

			self.logger.log({
				"validation/optimized_AUC": optimized_validation_auc,
				"test/optimized_AUC": optimized_test_auc,
				"test/ideal_AUC": ideal_test_auc,
			})

		out["F"] = F

class AUC_Optimizer(Problem):
	population_size = 100
	n_neighbours = 5
	log_every = 5
	def __init__(self, X_train, y_train, X_val, y_val, X_test, Y_test, logger=None):
		
		self.generation_number = 0

		self.X_train = X_train
		self.y_train = y_train
		self.X_val = X_val
		self.y_val = y_val
		self.X_TEST = X_test
		self.Y_TEST = Y_test
		self.logger = logger

		self.training_data = X_train
		self.n_instances = X_train.shape[0]
		
		super().__init__(
			n_var=self.n_instances,
			n_obj=1,               
			n_constr=0,            
			xl=0,                  
			xu=1,                  
			type_var=np.bool_,     
		)

	def _evaluate(self, x, out, *args, **kwargs):
		
		values = []
		for instance in x:
			inverse_AUC = 1
			if np.sum(instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(
					n_neighbors=AUC_Optimizer.n_neighbours
				)
				model.fit(
					self.X_train[instance], 
					self.y_train[instance]
				)

				y_pred = model.predict(self.X_val)
				inverse_AUC = 1 - roc_auc_score(self.y_val, y_pred)
			
			values.append(inverse_AUC)
		F = np.column_stack([values])
		self.generation_number += 1
		
		if self.logger is not None and self.generation_number % AUC_Optimizer.log_every == 0:
			validation_aucs = []
			test_aucs = []
			pareto_indices = NonDominatedSorting().do(F, only_non_dominated_front=True)
			
			for idx in pareto_indices:
				instance = x[idx]

				if np.sum(instance) >= AUC_Optimizer.n_neighbours:
					model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
					model.fit(
						self.X_train[instance], 
						self.y_train[instance]
					)
					y_pred = model.predict(self.X_val)
					validation_aucs.append(roc_auc_score(self.y_val, y_pred))
					y_pred = model.predict(self.X_TEST)
					test_aucs.append(roc_auc_score(self.Y_TEST, y_pred))
				else:
					validation_aucs.append(0)
					test_aucs.append(0)
					
			validation_idx = np.argmax(validation_aucs)
			test_idx = np.argmax(test_aucs)	
			x_ideal_validation_instance = self.X_train[x[pareto_indices[validation_idx]]]
			y_ideal_validation_instance = self.y_train[x[pareto_indices[validation_idx]]]
			x_ideal_test_instance = self.X_train[x[pareto_indices[test_idx]]]
			y_ideal_test_instance = self.y_train[x[pareto_indices[test_idx]]]

			if len(x_ideal_validation_instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(
					x_ideal_validation_instance, 
					y_ideal_validation_instance
				)

				y_pred = model.predict(self.X_val)
				optimized_validation_auc = roc_auc_score(self.y_val, y_pred)
				
				y_pred = model.predict(self.X_TEST)
				optimized_test_auc = roc_auc_score(self.Y_TEST, y_pred)
			else:
				optimized_validation_auc = 0
				optimized_test_auc = 0

			# Calculate metrics using ideal instance w.r.t test AUC
			if len(x_ideal_test_instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(
					x_ideal_test_instance, 
					y_ideal_test_instance
				)
				
				y_pred = model.predict(self.X_TEST)
				ideal_test_auc = roc_auc_score(self.Y_TEST, y_pred)
			else:
				ideal_test_auc

			self.logger.log({
				"validation/optimized_AUC": optimized_validation_auc,
				"test/optimized_AUC": optimized_test_auc,
				"test/ideal_AUC": ideal_test_auc,
			})

		out["F"] = F

class DiverseCustomSampling(Sampling):
	def __init__(self):
		super().__init__()

	def _do(self, problem, n_samples, **kwargs):

		target_inclusions = np.random.randint(
			problem.n_var // 3,
			problem.n_var,
			n_samples
		)
		init_pops = []
		for target in target_inclusions:
			array = np.array([1]*target + [0]*(problem.n_var - target))
			np.random.shuffle(array)
			init_pops.append(array)
		init_pops = np.array(init_pops, dtype=np.bool)
		return init_pops

class ConditionalVAE(nn.Module):
	def __init__(self, input_dim, label_dim, hidden_dim, latent_dim):
		super(ConditionalVAE, self).__init__()
		self.fc1 = nn.Linear(input_dim + label_dim, hidden_dim)
		self.fc_mu = nn.Linear(hidden_dim, latent_dim)
		self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
		self.fc2 = nn.Linear(latent_dim + label_dim, hidden_dim)
		self.fc3 = nn.Linear(hidden_dim, input_dim)

	def encode(self, x, y):
		# Concatenate input and label
		x = torch.cat([x, y], dim=1)
		h = torch.relu(self.fc1(x))
		return self.fc_mu(h), self.fc_logvar(h)

	def reparameterize(self, mu, logvar):
		std = torch.exp(0.5 * logvar)
		eps = torch.randn_like(std)
		return mu + eps * std

	def decode(self, z, y):
		# Concatenate latent vector and label
		z = torch.cat([z, y], dim=1)
		h = torch.relu(self.fc2(z))
		return self.fc3(h)

	def forward(self, x, y):
		mu, logvar = self.encode(x, y)
		z = self.reparameterize(mu, logvar)
		return self.decode(z, y), mu, logvar

class CustomDataset(Dataset):
	def __init__(self, x_synthetic, x_true):
		self.x = x_synthetic
		self.y = x_true
	def __len__(self):
		return self.x.shape[0]
	def __getitem__(self, ind):
		x = self.x[ind]
		y = self.y[ind]
		return x, y

def train(training_x, training_y, cvae, lr, epochs, batch_size, beta, logger=None):
	device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
	train_set = CustomDataset(torch.from_numpy(training_x), torch.from_numpy(training_y))
	train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
	optimizer = optim.Adam(cvae.parameters(), lr=lr)
	
	for epoch in range(epochs):
		cvae.train()
		total_loss = 0
		for batch in train_loader:
			x_batch = batch[0].to(device).float()
			y_batch = batch[1].to(device).float().unsqueeze(1)
			
			recon, mu, logvar = cvae(x_batch, y_batch)
			recon_loss = nn.MSELoss()(recon, x_batch)
			kl_div = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
			loss = recon_loss + (kl_div*beta)
	
			optimizer.zero_grad()
			loss.backward()
			optimizer.step()
			
			total_loss += loss.item()
		if logger is not None:
			logger.log({
				"training loss": total_loss / len(train_loader)
			})
		
	return cvae

def generate_synthetic_examples(x_samples, y_samples, sample_variance, cvae, num_samples=None):
	if num_samples is None:
		num_samples = len(x_samples)

	device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

	cvae.eval()

	synthetic_features = []

	while len(synthetic_features) < num_samples:
		with torch.no_grad():    
			x = torch.from_numpy(x_samples).to(device).float()
			y = torch.from_numpy(y_samples).to(device).float().unsqueeze(1)
			mu, logvar = cvae.encode(x, y)
			z = cvae.reparameterize(mu, logvar)
		minority_latents = z.cpu().numpy()

		minority_latents[:,0] += np.random.normal(-sample_variance[0]/2, sample_variance[0]/2, len(minority_latents))
		minority_latents[:,1] += np.random.normal(-sample_variance[1]/2, sample_variance[1]/2, len(minority_latents))

		with torch.no_grad():    
			z = torch.from_numpy(minority_latents).to(device).float()
			label_dim = torch.from_numpy(y_samples).to(device).float().unsqueeze(1)
			synthetic_minority_samples = cvae.decode(z, label_dim)
	
		for sample in synthetic_minority_samples.cpu().numpy():
			if len(synthetic_features) < num_samples:
				synthetic_features.append(sample)
			else:
				break
			

	return np.array(synthetic_features)

def calculate_latent_dimension_variance(x, y, cvae):
	device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
	with torch.no_grad():    
		x = torch.from_numpy(x).to(device).float()
		y = torch.from_numpy(y).to(device).float().unsqueeze(1)
		mu, logvar = cvae.encode(x, y)
		z = cvae.reparameterize(mu, logvar)
		total_latents = z.cpu().numpy()
		variance = np.var(total_latents, axis=0)
	
	return variance

def combine_sets(x1, y1, x2, y2):
	if len(x2) == 0:
		return x1, y1
	
	x = np.concatenate((x1, x2), axis=0)
	y = np.concatenate((y1, y2), axis=0)
	return x, y

def select_synthetic_survivors(result, x_train, y_train, x_validation, y_validation, real_samples, auc_selection_threshold):
	selected_samples = []
	sample_AUCs = []
	for individual in result.pop:

		if np.sum(individual.X) > AUC_Optimizer.n_neighbours:
			model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
			model.fit(x_train[individual.X], y_train[individual.X])
			y_pred = model.predict(x_validation)
			optimized_AUC = roc_auc_score(y_validation, y_pred)

			if optimized_AUC > auc_selection_threshold:
				for sample in x_train[individual.X]:
					for real_sample in real_samples:
						if np.all(sample == real_sample):
							break
					else:
						for saved_sample in selected_samples:
							if np.all(sample == saved_sample):
								break
						else:
							sample_AUCs.append(optimized_AUC)
							selected_samples.append(sample)
	
	idx = np.argsort(sample_AUCs)
	top_idx = idx[:10]
	arr = np.array(selected_samples)

	return arr[top_idx]

def split_info(data_key):
	segments = data_key.split('_')
	split_num = segments[0]
	dataset_name = '_'.join(segments[1:])
	return split_num, dataset_name

def calculate_IR(labels):
	counts = pd.DataFrame(labels).value_counts()
	return counts.max()/counts.min()

# %%
data_key_iters = {}
for file in os.listdir("results"):
	segments = file.split(" ")
	data_key = segments[0]
	if data_key not in data_key_iters:
		data_key_iters[data_key] = []
	
	data_key_iters[data_key].append(file)

# %%
splits = pd.read_csv('data_splits.csv')
splits.columns
# Out:
# Index(['abalone-17_vs_7-8-9-10', 'abalone-20_vs_8-9-10', 'abalone-21_vs_8',
#        'abalone-3_vs_11', 'abalone19', 'abalone9-18', 'cleveland-0_vs_4',
#        'ecoli-0-1-4-7_vs_2-3-5-6', 'ecoli-0-1-4-7_vs_5-6',
#        'ecoli-0-2-6-7_vs_3-5', 'ecoli-0-4-6_vs_5', 'ecoli-0-6-7_vs_3-5',
#        'ecoli4', 'glass-0-6_vs_5', 'winequality-red-4',
#        'winequality-red-8_vs_6-7', 'winequality-white-9_vs_4', 'wisconsin',
#        'yeast-0-2-5-7-9_vs_3-6-8', 'yeast-2_vs_4'],
#       dtype='object')

# %%
competitor = {}
for split_name in splits:
	for idx in range(31):

		results = {}
		data_key = f"{idx}_{split_name}"

		x_train = data_mapper[data_key]["x_train"]
		y_train = data_mapper[data_key]["y_train"]

		# x_validation = data_mapper[data_key]["x_validation"]
		# y_validation = data_mapper[data_key]["y_validation"]

		# x_comb = np.concatenate((x_train, x_validation), axis=0)
		# y_comb = np.concatenate((y_train, y_validation), axis=0)
		x_comb = x_train
		y_comb = y_train
		
		x_test = data_mapper[data_key]["x_test"]
		y_test = data_mapper[data_key]["y_test"]

		try:
			smote = SMOTE(sampling_strategy='minority') 
			x, y = smote.fit_resample(x_comb, y_comb)
			model = KNeighborsClassifier(n_neighbors=5)
			model.fit(x, y)
			y_pred = model.predict(x_test)
			results['SMOTE'] = roc_auc_score(y_test, y_pred)
		except:
			results['SMOTE'] = 0

		try:
			adasyn = ADASYN(sampling_strategy='minority')
			x, y = adasyn.fit_resample(x_comb, y_comb)
			model = KNeighborsClassifier(n_neighbors=5)
			model.fit(x, y)
			y_pred = model.predict(x_test)
			results['ADASYN'] = roc_auc_score(y_test, y_pred)
		except:
			results['ADASYN'] = 0
		
		try:
			blsmote = BorderlineSMOTE(sampling_strategy='minority', kind='borderline-1')
			x, y = blsmote.fit_resample(x_comb, y_comb)
			model = KNeighborsClassifier(n_neighbors=5)
			model.fit(x, y)
			y_pred = model.predict(x_test)
			results['Borderline SMOTE'] = roc_auc_score(y_test, y_pred)
		except:
			results['Borderline SMOTE'] = 0

		try:
			smt_tomek = SMOTETomek(sampling_strategy='auto')
			x, y = smt_tomek.fit_resample(x_comb, y_comb)
			model = KNeighborsClassifier(n_neighbors=5)
			model.fit(x, y)
			y_pred = model.predict(x_test)
			results['SMOTE Tomek'] = roc_auc_score(y_test, y_pred)
		except:
			results['SMOTE Tomek'] = 0
		
		try:
			smt_eenn = SMOTEENN(sampling_strategy='auto')
			x, y = smt_eenn.fit_resample(x_comb, y_comb)
			model = KNeighborsClassifier(n_neighbors=5)
			model.fit(x, y)
			y_pred = model.predict(x_test)
			results['SMOTE EENN'] = roc_auc_score(y_test, y_pred)
		except:
			results['SMOTE EENN'] = 0

		competitor[data_key] = results
competitor
# Out:
# {'0_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7157894736842105),
#   'ADASYN': np.float64(0.6783208020050125),
#   'Borderline SMOTE': np.float64(0.7184210526315791),
#   'SMOTE Tomek': np.float64(0.7114035087719298),
#   'SMOTE EENN': np.float64(0.7418546365914787)},
#  '1_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7506265664160401),
#   'ADASYN': np.float64(0.7140350877192982),
#   'Borderline SMOTE': np.float64(0.7201754385964912),
#   'SMOTE Tomek': np.float64(0.713157894736842),
#   'SMOTE EENN': np.float64(0.775814536340852)},
#  '2_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.712280701754386),
#   'ADASYN': np.float64(0.7096491228070174),
#   'Borderline SMOTE': np.float64(0.6783208020050125),
#   'SMOTE Tomek': np.float64(0.6739348370927318),
#   'SMOTE EENN': np.float64(0.7714285714285715)},
#  '3_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.8419799498746867),
#   'ADASYN': np.float64(0.8411027568922306),
#   'Borderline SMOTE': np.float64(0.8176691729323309),
#   'SMOTE Tomek': np.float64(0.8794486215538848),
#   'SMOTE EENN': np.float64(0.8671679197994988)},
#  '4_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.8220551378446116),
#   'ADASYN': np.float64(0.7854636591478696),
#   'Borderline SMOTE': np.float64(0.8220551378446116),
#   'SMOTE Tomek': np.float64(0.8203007518796993),
#   'SMOTE EENN': np.float64(0.8472431077694235)},
#  '5_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.8595238095238095),
#   'ADASYN': np.float64(0.8595238095238095),
#   'Borderline SMOTE': np.float64(0.8317042606516292),
#   'SMOTE Tomek': np.float64(0.8604010025062656),
#   'SMOTE EENN': np.float64(0.8472431077694235)},
#  '6_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7462406015037593),
#   'ADASYN': np.float64(0.7114035087719298),
#   'Borderline SMOTE': np.float64(0.7192982456140351),
#   'SMOTE Tomek': np.float64(0.7497493734335839),
#   'SMOTE EENN': np.float64(0.7731829573934836)},
#  '7_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.8882205513784461),
#   'ADASYN': np.float64(0.8855889724310777),
#   'Borderline SMOTE': np.float64(0.8533834586466165),
#   'SMOTE Tomek': np.float64(0.8882205513784461),
#   'SMOTE EENN': np.float64(0.9429824561403508)},
#  '8_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7828320802005012),
#   'ADASYN': np.float64(0.7462406015037593),
#   'Borderline SMOTE': np.float64(0.7236842105263158),
#   'SMOTE Tomek': np.float64(0.712280701754386),
#   'SMOTE EENN': np.float64(0.8106516290726818)},
#  '9_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0
abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7506265664160401),
#   'ADASYN': np.float64(0.7105263157894737),
#   'Borderline SMOTE': np.float64(0.6774436090225564),
#   'SMOTE Tomek': np.float64(0.6756892230576441),
#   'SMOTE EENN': np.float64(0.850751879699248)},
#  '22_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7819548872180451),
#   'ADASYN': np.float64(0.7810776942355889),
#   'Borderline SMOTE': np.float64(0.7532581453634085),
#   'SMOTE Tomek': np.float64(0.7810776942355889),
#   'SMOTE EENN': np.float64(0.8097744360902257)},
#  '23_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.850751879699248),
#   'ADASYN': np.float64(0.8463659147869674),
#   'Borderline SMOTE': np.float64(0.7898496240601504),
#   'SMOTE Tomek': np.float64(0.8489974937343358),
#   'SMOTE EENN': np.float64(0.8375939849624059)},
#  '24_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.8176691729323309),
#   'ADASYN': np.float64(0.8167919799498747),
#   'Borderline SMOTE': np.float64(0.8229323308270677),
#   'SMOTE Tomek': np.float64(0.8194235588972432),
#   'SMOTE EENN': np.float64(0.8463659147869674)},
#  '25_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7644110275689222),
#   'ADASYN': np.float64(0.7313283208020049),
#   'Borderline SMOTE': np.float64(0.806265664160401),
#   'SMOTE Tomek': np.float64(0.7644110275689222),
#   'SMOTE EENN': np.float64(0.8279448621553884)},
#  '26_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.856892230576441),
#   'ADASYN': np.float64(0.8194235588972432),
#   'Borderline SMOTE': np.float64(0.8299498746867169),
#   'SMOTE Tomek': np.float64(0.8533834586466165),
#   'SMOTE EENN': np.float64(0.8864661654135337)},
#  '27_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7819548872180451),
#   'ADASYN': np.float64(0.7401002506265663),
#   'Borderline SMOTE': np.float64(0.7863408521303259),
#   'SMOTE Tomek': np.float64(0.7793233082706766),
#   'SMOTE EENN': np.float64(0.8428571428571427)},
#  '28_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7837092731829574),
#   'ADASYN': np.float64(0.8176691729323309),
#   'Borderline SMOTE': np.float64(0.7523809523809524),
#   'SMOTE Tomek': np.float64(0.7436090225563909),
#   'SMOTE EENN': np.float64(0.806265664160401)},
#  '29_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7837092731829574),
#   'ADASYN': np.float64(0.7854636591478696),
#   'Borderline SMOTE': np.float64(0.7977443609022556),
#   'SMOTE Tomek': np.float64(0.7863408521303259),
#   'SMOTE EENN': np.float64(0.775814536340852)},
#  '30_abalone-17_vs_7-8-9-10': {'SMOTE': np.float64(0.7497493734335839),
#   'ADASYN': np.float64(0.7436090225563909),
#   'Borderline SMOTE': np.float64(0.7140350877192982),
#   'SMOTE Tomek': np.float64(0.7453634085213032),
#   'SMOTE EENN': np.float64(0.7401002506265663)},
#  '0_abalone-20_vs_8-9-10': {'SMOTE': np.float64(0.7005145278450363),
#   'ADASYN': np.float64(0.7005145278450363),
#   'Borderline SMOTE': np.float64(0.6322639225181598),
#   'SMOTE Tomek': np.float64(0.7015738498789346),
#   'SMOTE EENN': np.float64(0.6920399515738499)},
#  '1_abalone-20_vs_8-9-10': {'SMOTE': np.float64(0.8195912614517264),
#   'ADASYN': np.float64(0.8185341789992953),
#   'Borderline SMOTE': np.float64(0.7457716701902749),
#   'SMOTE Tomek': np.float64(0.8195912614517264),
#   'SMOTE EENN': np.float64(0.817477096546864)},
#  '2_abalone-20_vs_8-9-10': {'SMOTE': np.float64(0.7225158562367866),
#   'ADASYN': np.float64(0.7225158562367866),
#   'Borderline SMOTE': np.float64(0.7320295983086681),
#   'SMOTE Tomek': np.float64(0.7225158562367866),
#   'SMOTE EENN': np.float64(0.7214587737843552)},
#  '3_abalone-20_vs_8-9-10': {'SMOTE': np.float64(0.

#   'Borderline SMOTE': np.float64(0.9894366197183099),
#   'SMOTE Tomek': np.float64(0.9894366197183099),
#   'SMOTE EENN': np.float64(0.9894366197183099)},
#  '21_abalone-21_vs_8': {'SMOTE': np.float64(0.8227699530516431),
#   'ADASYN': np.float64(0.8227699530516431),
#   'Borderline SMOTE': np.float64(0.6596244131455399),
#   'SMOTE Tomek': np.float64(0.8227699530516431),
#   'SMOTE EENN': np.float64(0.8157276995305164)},
#  '22_abalone-21_vs_8': {'SMOTE': np.float64(0.8192488262910798),
#   'ADASYN': np.float64(0.8192488262910798),
#   'Borderline SMOTE': np.float64(0.8192488262910798),
#   'SMOTE Tomek': np.float64(0.8192488262910798),
#   'SMOTE EENN': np.float64(0.8157276995305164)},
#  '23_abalone-21_vs_8': {'SMOTE': np.float64(0.8051643192488263),
#   'ADASYN': np.float64(0.7981220657276995),
#   'Borderline SMOTE': np.float64(0.6525821596244131),
#   'SMOTE Tomek': np.float64(0.8051643192488263),
#   'SMOTE EENN': np.float64(0.8016431924882628)},
#  '24_abalone-21_vs_8': {'SMOTE': np.float64(0.9612676056338028),
#   'ADASYN': np.float64(0.9612676056338028),
#   'Borderline SMOTE': np.float64(0.9894366197183099),
#   'SMOTE Tomek': np.float64(0.9647887323943661),
#   'SMOTE EENN': np.float64(0.9577464788732395)},
#  '25_abalone-21_vs_8': {'SMOTE': np.float64(0.6525821596244131),
#   'ADASYN': np.float64(0.6525821596244131),
#   'Borderline SMOTE': np.float64(0.6525821596244131),
#   'SMOTE Tomek': np.float64(0.6525821596244131),
#   'SMOTE EENN': np.float64(0.6525821596244131)},
#  '26_abalone-21_vs_8': {'SMOTE': np.float64(0.8016431924882628),
#   'ADASYN': np.float64(0.8016431924882628),
#   'Borderline SMOTE': np.float64(0.8086854460093896),
#   'SMOTE Tomek': np.float64(0.8016431924882628),
#   'SMOTE EENN': np.float64(0.7981220657276995)},
#  '27_abalone-21_vs_8': {'SMOTE': np.float64(0.9823943661971831),
#   'ADASYN': np.float64(0.9823943661971831),
#   'Borderline SMOTE': np.float64(0.9929577464788732),
#   'SMOTE Tomek': np.float64(0.9718309859154929),
#   'SMOTE EENN': np.float64(0.9859154929577465)},
#  '28_abalone-21_vs_8': {'SMOTE': np.float64(0.6455399061032864),
#   'ADASYN': np.float64(0.6349765258215961),
#   'Borderline SMOTE': np.float64(0.6455399061032864),
#   'SMOTE Tomek': np.float64(0.6384976525821596),
#   'SMOTE EENN': np.float64(0.7981220657276995)},
#  '29_abalone-21_vs_8': {'SMOTE': np.float64(0.9647887323943661),
#   'ADASYN': np.float64(0.9647887323943661),
#   'Borderline SMOTE': np.float64(0.9894366197183099),
#   'SMOTE Tomek': np.float64(0.9683098591549295),
#   'SMOTE EENN': np.float64(0.9647887323943661)},
#  '30_abalone-21_vs_8': {'SMOTE': np.float64(0.7981220657276995),
#   'ADASYN': np.float64(0.7946009389671361),
#   'Borderline SMOTE': np.float64(0.8086854460093896),
#   'SMOTE Tomek': np.float64(0.8016431924882628),
#   'SMOTE EENN': np.float64(0.7875586854460094)},
#  '0_abalone-3_vs_11': {'SMOTE': np.float64(1.0),
#   'ADASYN': np.float64(1.0),
#   'Borderline SMOTE': np.float64(1.0),
#   'SMOTE Tomek': np.float64(1.0),
#   'SMOTE EENN': np.float64(1.0)},
#  
#   'SMOTE EENN': np.float64(0.6959537572254335)},
#  '18_abalone9-18': {'SMOTE': np.float64(0.707514450867052),
#   'ADASYN': np.float64(0.7046242774566475),
#   'Borderline SMOTE': np.float64(0.7219653179190753),
#   'SMOTE Tomek': np.float64(0.707514450867052),
#   'SMOTE EENN': np.float64(0.684393063583815)},
#  '19_abalone9-18': {'SMOTE': np.float64(0.6691331923890064),
#   'ADASYN': np.float64(0.7629492600422833),
#   'Borderline SMOTE': np.float64(0.6982029598308668),
#   'SMOTE Tomek': np.float64(0.6604122621564482),
#   'SMOTE EENN': np.float64(0.7822410147991543)},
#  '20_abalone9-18': {'SMOTE': np.float64(0.6921965317919077),
#   'ADASYN': np.float64(0.680635838150289),
#   'Borderline SMOTE': np.float64(0.7095375722543352),
#   'SMOTE Tomek': np.float64(0.6777456647398845),
#   'SMOTE EENN': np.float64(0.7104046242774568)},
#  '21_abalone9-18': {'SMOTE': np.float64(0.8132947976878613),
#   'ADASYN': np.float64(0.7604046242774566),
#   'Borderline SMOTE': np.float64(0.7950867052023121),
#   'SMOTE Tomek': np.float64(0.7459537572254336),
#   'SMOTE EENN': np.float64(0.819942196531792)},
#  '22_abalone9-18': {'SMOTE': np.float64(0.7748554913294796),
#   'ADASYN': np.float64(0.780635838150289),
#   'Borderline SMOTE': np.float64(0.7421965317919076),
#   'SMOTE Tomek': np.float64(0.8248554913294798),
#   'SMOTE EENN': np.float64(0.7930635838150291)},
#  '23_abalone9-18': {'SMOTE': np.float64(0.8306025369978859),
#   'ADASYN': np.float64(0.8335095137420719),
#   'Borderline SMOTE': np.float64(0.8625792811839325),
#   'SMOTE Tomek': np.float64(0.836416490486258),
#   'SMOTE EENN': np.float64(0.839323467230444)},
#  '24_abalone9-18': {'SMOTE': np.float64(0.751321353065539),
#   'ADASYN': np.float64(0.8025898520084567),
#   'Borderline SMOTE': np.float64(0.7542283298097251),
#   'SMOTE Tomek': np.float64(0.8054968287526427),
#   'SMOTE EENN': np.float64(0.7735200845665962)},
#  '25_abalone9-18': {'SMOTE': np.float64(0.6835260115606937),
#   'ADASYN': np.float64(0.7277456647398844),
#   'Borderline SMOTE': np.float64(0.6921965317919077),
#   'SMOTE Tomek': np.float64(0.6719653179190751),
#   'SMOTE EENN': np.float64(0.6546242774566474)},
#  '26_abalone9-18': {'SMOTE': np.float64(0.7629492600422833),
#   'ADASYN': np.float64(0.8113107822410148),
#   'Borderline SMOTE': np.float64(0.7494714587737844),
#   'SMOTE Tomek': np.float64(0.7716701902748414),
#   'SMOTE EENN': np.float64(0.7793340380549684)},
#  '27_abalone9-18': {'SMOTE': np.float64(0.7893063583815029),
#   'ADASYN': np.float64(0.7893063583815029),
#   'Borderline SMOTE': np.float64(0.8153179190751446),
#   'SMOTE Tomek': np.float64(0.780635838150289),
#   'SMOTE EENN': np.float64(0.7199421965317919)},
#  '28_abalone9-18': {'SMOTE': np.float64(0.6982029598308668),
#   'ADASYN': np.float64(0.6923890063424947),
#   'Borderline SMOTE': np.float64(0.704016913319239),
#   'SMOTE Tomek': np.float64(0.7378435517970401),
#   'SMOTE EENN': np.float64(0.734936575052854)},
#  '29_abalone9-18': {'SMOTE': np.float64(0.7479768786127168),
#   'ADASYN': np.float64(0.6893063583815029),
#   'Borderline SMOTE': np.float64(0.7595375722543354),
#   'SMOTE Tomek': np.float64(0.6950867052023121),
#   'SMOTE EENN': np.float64(0.6835260115606937)},
#  '30_abalone9-18': {'SMOTE': np.float64(0.8248554913294798),
#   'ADASYN': np.float64(0.8450867052023121),
#   'Borderline SMOTE': np.float64(0.7624277456647399),
#   'SMOTE Tomek': np.float64(0.8364161849710983),
#   'SMOTE EENN': np.float64(0.8575144508670519)},
#  '0_cleveland-0_vs_4': {'SMOTE': np.float64(0.9874999999999999),
#   'ADASYN': np.float64(0.975),
#   'Borderline SMOTE': np.float64(1.0),
#   'SMOTE Tomek': np.float64(1.0),
#   'SMOTE EENN': np.float64(0.9874999999999999)},
#  '1_cleveland-0_vs_4': {'SMOTE': np.float64(0.7708333333333333),
#   'ADASYN': np.float64(0.7833333333333333),
#   'Borderline SMOTE': np.float64(0.7833333333333333),
#   'SMOTE Tomek': np.float64(0.7708333333333333),
#   'SMOTE EENN': np.float64(0.7833333333333333)},
#  '2_cleveland-0_vs_4': {'SMOTE': np.float64(0.9874999999999999),
#   'ADASYN': np.float64(0.975),
#   'Borderline SMOTE': np.float64(0.9874999999999999),
#   'SMOTE Tomek': np.float64(0.9874999999999999),
#   'SMOTE EENN': np.float64(0.9874999999999999)},
#  '3_cleveland-0_vs_4': {'SMOTE': np.float64(0.9375),
#   'ADASYN': np.float64(0.9375),
#   'Borderline SMOTE': np.float64(0.9500000000000001),
#   'SMOTE Tomek': np.float64(0.9500000000000001),
#   'SMOTE EENN': np.float64(0.9375)},
#  '4_cleveland-0_vs_4': {'SMOTE': np.float64(0.975),
#   'ADASYN': np.float64(0.9874999999999999),
#   'Borderline SMOTE': np.float64(0.9874999999999999),
#   'SMOTE Tomek': np.float64(0.975),
#   'SMOTE EENN': np.float64(0.9874999999999999)},
#  '5_cleveland-0_vs_4': {'SMOTE': np.float64(0.7833333333333333),
#   'ADASYN': np.float64(0.7833333333333333),
#   'Borderline SMOTE': np.float64(0.7833333333333333),
#   'SMOTE Tomek': np.float64(0.7708333333333333),
#   'SMOTE EENN': np.float64(0.7583333333333333)},
#  '6_cleveland-0_vs_4': {'SMOTE': np.float64(0.7958333333333333),
#   'ADASYN': np.float64(0.7833333333333333),
#   'Borderline SMOTE': np.float64(0.7958333333333333),
#   'SMOTE Tomek': np.float64(0.7833333333333333),
#   'SMOTE EENN': np.float64(0.7958333333333333)},
# ...
#   'ADASYN': np.float64(0.9513274336283185),
#   'Borderline SMOTE': np.float64(0.9423893805309734),
#   'SMOTE Tomek': np.float64(0.9668141592920354),
#   'SMOTE EENN': np.float64(0.9513274336283185)},
#  '2_yeast-0-2-5-7-9_vs_3-6-8': {'SMOTE': np.float64(0.9285058737151248),
#   'ADASYN': np.float64(0.9096916299559472),
#   'Borderline SMOTE': np.float64(0.9319016152716593),
#   'SMOTE Tomek': np.float64(0.9307085168869311),
#   'SMOTE EENN': np.float64(0.9130873715124816)},
#  '3_yeast-0-2-5-7-9_vs_3-6-8': {'SMOTE': np.float64(0.
yeast-0-2-5-7-9_vs_3-6-8': {'SMOTE': np.float64(0.9380530973451328),
#   'ADASYN': np.float64(0.9048672566371682),
#   'Borderline SMOTE': np.float64(0.9335398230088495),
#   'SMOTE Tomek': np.float64(0.9269911504424779),
#   'SMOTE EENN': np.float64(0.915929203539823)},
#  '29_yeast-0-2-5-7-9_vs_3-6-8': {'SMOTE': np.float64(0.8880323054331866),
#   'ADASYN': np.float64(0.8638032305433186),
#   'Borderline SMOTE': np.float64(0.8573788546255506),
#   'SMOTE Tomek': np.float64(0.8814243759177681),
#   'SMOTE EENN': np.float64(0.897852422907489)},
#  '30_yeast-0-2-5-7-9_vs_3-6-8': {'SMOTE': np.float64(0.8846902654867255),
#   'ADASYN': np.float64(0.8559292035398229),
#   'Borderline SMOTE': np.float64(0.8646902654867256),
#   'SMOTE Tomek': np.float64(0.8736283185840708),
#   'SMOTE EENN': np.float64(0.8625663716814158)},
#  '0_yeast-2_vs_4': {'SMOTE': np.float64(0.8411371237458194),
#   'ADASYN': np.float64(0.870903010033445),
#   'Borderline SMOTE': np.float64(0.8926421404682275),
#   'SMOTE Tomek': np.float64(0.8454849498327759),
#   'SMOTE EENN': np.float64(0.8795986622073579)},
#  '1_yeast-2_vs_4': {'SMOTE': np.float64(0.8715719063545151),
#   'ADASYN': np.float64(0.862876254180602),
#   'Borderline SMOTE': np.float64(0.8331103678929767),
#   'SMOTE Tomek': np.float64(0.8672240802675585),
#   'SMOTE EENN': np.float64(0.8715719063545151)},
#  '2_yeast-2_vs_4': {'SMOTE': np.float64(0.8951149425287357),
#   'ADASYN': np.float64(0.8864942528735633),
#   'Borderline SMOTE': np.float64(0.8908045977011495),
#   'SMOTE Tomek': np.float64(0.899425287356322),
#   'SMOTE EENN': np.float64(0.9367816091954022)},
#  '3_yeast-2_vs_4': {'SMOTE': np.float64(0.853448275862069),
#   'ADASYN': np.float64(0.8491379310344828),
#   'Borderline SMOTE': np.float64(0.8491379310344828),
#   'SMOTE Tomek': np.float64(0.8491379310344828),
#   'SMOTE EENN': np.float64(0.8821839080459771)},
#  '4_yeast-2_vs_4': {'SMOTE': np.float64(0.8620689655172413),
#   'ADASYN': np.float64(0.8577586206896552),
#   'Borderline SMOTE': np.float64(0.8204022988505746),
#   'SMOTE Tomek': np.float64(0.8204022988505746),
#   'SMOTE EENN': np.float64(0.853448275862069)},
#  '5_yeast-2_vs_4': {'SMOTE': np.float64(0.814655172413793),
#   'ADASYN': np.float64(0.814655172413793),
#   'Borderline SMOTE': np.float64(0.7600574712643677),
#   'SMOTE Tomek': np.float64(0.8189655172413793),
#   'SMOTE EENN': np.float64(0.8563218390804599)},
#  '6_yeast-2_vs_4': {'SMOTE': np.float64(0.8454849498327759),
#   'ADASYN': np.float64(0.870903010033445),
#   'Borderline SMOTE': np.float64(0.8498327759197324),
#   'SMOTE Tomek': np.float64(0.8926421404682275),
#   'SMOTE EENN': np.float64(0.8839464882943144)},
#  '7_yeast-2_vs_4': {'SMOTE': np.float64(0.9354515050167224),
#   'ADASYN': np.float64(0.8882943143812708),
#   'Borderline SMOTE': np.float64(0.811371237458194),
#   'SMOTE Tomek': np.float64(0.9013377926421405),
#   'SMOTE EENN': np.float64(0.820066889632107)},
#   'SMOTE Tomek': np.float64(0.9195402298850573),
#   'SMOTE EENN': np.float64(0.8864942528735633)},
#  '19_yeast-2_vs_4': {'SMOTE': np.float64(0.9441471571906355),
#   'ADASYN': np.float64(0.9180602006688964),
#   'Borderline SMOTE': np.float64(0.939799331103679),
#   'SMOTE Tomek': np.float64(0.931103678929766),
#   'SMOTE EENN': np.float64(0.9354515050167224)},
#  '20_yeast-2_vs_4': {'SMOTE': np.float64(0.8606321839080461),
#   'ADASYN': np.float64(0.8936781609195402),
#   'Borderline SMOTE': np.float64(0.8778735632183909),
#   'SMOTE Tomek': np.float64(0.8692528735632185),
#   'SMOTE EENN': np.float64(0.8606321839080461)},
#  '21_yeast-2_vs_4': {'SMOTE': np.float64(0.8491379310344828),
#   'ADASYN': np.float64(0.8864942528735633),
#   'Borderline SMOTE': np.float64(0.8735632183908046),
#   'SMOTE Tomek': np.float64(0.8864942528735633),
#   'SMOTE EENN': np.float64(0.9281609195402298)},
#  '22_yeast-2_vs_4': {'SMOTE': np.float64(0.8498327759197324),
#   'ADASYN': np.float64(0.8498327759197324),
#   'Borderline SMOTE': np.float64(0.8541806020066889),
#   'SMOTE Tomek': np.float64(0.8454849498327759),
#   'SMOTE EENN': np.float64(0.8411371237458194)},
#  '23_yeast-2_vs_4': {'SMOTE': np.float64(0.8692528735632185),
#   'ADASYN': np.float64(0.8692528735632185),
#   'Borderline SMOTE': np.float64(0.8692528735632185),
#   'SMOTE Tomek': np.float64(0.8735632183908046),
#   'SMOTE EENN': np.float64(0.8649425287356323)},
#  '24_yeast-2_vs_4': {'SMOTE': np.float64(0.8951149425287357),
#   'ADASYN': np.float64(0.8778735632183909),
#   'Borderline SMOTE': np.float64(0.8864942528735633),
#   'SMOTE Tomek': np.float64(0.8951149425287357),
#   'SMOTE EENN': np.float64(0.8951149425287357)},
#  '25_yeast-2_vs_4': {'SMOTE': np.float64(0.8882943143812708),
#   'ADASYN': np.float64(0.9267558528428094),
#   'Borderline SMOTE': np.float64(0.9224080267558529),
#   'SMOTE Tomek': np.float64(0.8795986622073579),
#   'SMOTE EENN': np.float64(0.9652173913043478)},
#  '26_yeast-2_vs_4': {'SMOTE': np.float64(0.8585284280936454),
#   'ADASYN': np.float64(0.8541806020066889),
#   'Borderline SMOTE': np.float64(0.7561872909698996),
#   'SMOTE Tomek': np.float64(0.8585284280936454),
#   'SMOTE EENN': np.float64(0.8244147157190636)},
#  '27_yeast-2_vs_4': {'SMOTE': np.float64(0.9367816091954022),
#   'ADASYN': np.float64(0.9195402298850573),
#   'Borderline SMOTE': np.float64(0.9238505747126436),
#   'SMOTE Tomek': np.float64(0.932471264367816),
#   'SMOTE EENN': np.float64(0.8706896551724138)},
#  '28_yeast-2_vs_4': {'SMOTE': np.float64(0.9022988505747126),
#   'ADASYN': np.float64(0.8850574712643677),
#   'Borderline SMOTE': np.float64(0.8433908045977012),
#   'SMOTE Tomek': np.float64(0.8936781609195402),
#   'SMOTE EENN': np.float64(0.8936781609195402)},
#  '29_yeast-2_vs_4': {'SMOTE': np.float64(0.8541806020066889),
#   'ADASYN': np.float64(0.8839464882943144),
#   'Borderline SMOTE': np.float64(0.8585284280936454),
#   'SMOTE Tomek': np.float64(0.8244147157190636),
#   'SMOTE EENN': np.float64(0.8411371237458194)},
#  '30_yeast-2_vs_4': {'SMOTE': np.float64(0.9013377926421405),
#   'ADASYN': np.float64(0.896989966555184),
#   'Borderline SMOTE': np.float64(0.8585284280936454),
#   'SMOTE Tomek': np.float64(0.896989966555184),
#   'SMOTE EENN': np.float64(0.862876254180602)}}

# %%
for dataset in splits.columns:

	synthetic_optimized_auc = []
	baseline_optimized_auc = []
	baseline_auc = []
	for data_key in splits[dataset]:
		x_train = data_mapper[data_key]['x_train'] 
		y_train = data_mapper[data_key]['y_train']
		x_validation = data_mapper[data_key]['x_validation'] 
		y_validation = data_mapper[data_key]['y_validation']
		x_test = data_mapper[data_key]['x_test'] 
		y_test = data_mapper[data_key]['y_test']

		max_validation_AUC = []
		result_by_idx = []

		model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		model.fit(x_train, y_train)
		y_pred = model.predict(x_test)
		baseline_auc.append(roc_auc_score(y_test, y_pred))
		# y_pred = model.predict(x_test)
		
		if data_key not in data_key_iters: continue
		
		for generation_file in data_key_iters[data_key]:
			with open(f"results/{generation_file}", "rb") as fh:
				result_dict = pickle.load(fh)

			validation_auc = []
			test_auc = []

			# for individual in result_dict['Result'].pop: >> No NDS
			# 	instance = individual.X
			for instance in result_dict['Result'].X:
				if np.sum(instance) >= AUC_Optimizer.n_neighbours:
					model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
					model.fit(result_dict['Base x_train'][instance], result_dict['Base y_train'][instance] )
					y_pred = model.predict(x_validation)
					validation_auc.append(roc_auc_score(y_validation, y_pred))
					# y_pred = model.predict(x_test)
					# test_auc.append(roc_auc_score(y_test, y_pred))
				else:
					validation_auc.append(0)
					# test_auc.append(0)

			# validation_idx = np.argmax(validation_auc)
			max_validation_AUC.append(np.max(validation_auc))
			result_by_idx.append(result_dict)
			# test_idx = np.argmax(test_auc)	
			# validation_ideal_x_train = result_dict['Base x_train'][result_dict['Result'].X[validation_idx]]
			# validation_ideal_y_train = result_dict['Base y_train'][result_dict['Result'].X[validation_idx]]
			# test_ideal_x_train = result_dict['Base x_train'][result_dict['Result'].X[test_idx]]
			# test_ideal_y_train = result_dict['Base y_train'][result_dict['Result'].X[test_idx]]

		best_generation_idx = np.argmax(max_validation_AUC)
		synthetic_optimized_auc.append(np.max(max_validation_AUC))
		best_result = result_by_idx[best_generation_idx]
		
		test_auc = []
		for instance in best_result['Result'].X:
			if np.sum(instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(best_result['Base x_train'][instance], best_result['Base y_train'][instance] )
				y_pred = model.predict(x_test)
				test_auc.append(roc_auc_score(y_test, y_pred))
			else:
				test_auc.append(0)
		test_idx = np.argmax(test_auc)

		test_ideal_x_train = best_result['Base x_train'][best_result['Result'].X[test_idx]]
		test_ideal_y_train = best_result['Base y_train'][best_result['Result'].X[test_idx]]

		model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		model.fit(test_ideal_x_train, test_ideal_y_train)
		y_pred = model.predict(x_test)
		synthetic_optimized_auc.append(roc_auc_score(y_test, y_pred))

		#########################################
		#
		##########################################

		problem = AUC_Filter(
			x_train, y_train, 
			x_validation, y_validation,
			X_test=x_test, Y_test=y_test,
		)
		algorithm = NSGA2(pop_size=AUC_Optimizer.population_size, sampling=DiverseCustomSampling(), crossover=HUX(), mutation=BitflipMutation(), eliminate_duplicates=True)
		result = minimize(problem, algorithm, ('n_gen', AUC_Optimizer.population_size), save_history=False)
		
		for instance in result.X:
			if np.sum(instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(x_train[instance], y_train[instance] )
				y_pred = model.predict(x_test)
				test_auc.append(roc_auc_score(y_test, y_pred))
			else:
				test_auc.append(0)

		baseline_optimized_auc.append(np.max(test_auc))
	print(f"\n{dataset}: ")
	print(f"  PVAL:             {round(ranksums(baseline_optimized_auc, synthetic_optimized_auc).pvalue, 4)}  {"TRUE" if round(ranksums(baseline_optimized_auc, synthetic_optimized_auc).pvalue, 4) < 0.05 else "FALSE"}")
	print(f"  Mean synthOve AUC {round(np.mean(synthetic_optimized_auc), 4)}")
	print(f"  Mean baseline AUC {round(np.mean(baseline_optimized_auc), 4)} ")
	print(f"  Mean noOptimi AUC {round(np.mean(baseline_auc), 4)}")
# Out:
# abalone-17_vs_7-8-9-10:
#   PVAL:             0.0022  TRUE
#   Mean synthOve AUC 0.7619
#   Mean baseline AUC 0.7016
#   Mean noOptimi AUC 0.5259
#
# abalone-20_vs_8-9-10:
#   PVAL:             0.0381  TRUE
#   Mean synthOve AUC 0.8021
#   Mean baseline AUC 0.7542
#   Mean noOptimi AUC 0.5302
#
# abalone-21_vs_8:
#   PVAL:             0.1157  FALSE
#   Mean synthOve AUC 0.9162
#   Mean baseline AUC 0.8859
#   Mean noOptimi AUC 0.6771
#
# abalone-3_vs_11:
#   PVAL:             0.4509  FALSE
#   Mean synthOve AUC 0.9991
#   Mean baseline AUC 0.9987
#   Mean noOptimi AUC 1.0
#
# abalone19:
#   PVAL:             0.6277  FALSE
#   Mean synthOve AUC 0.504
#   Mean baseline AUC 0.5
#   Mean noOptimi AUC 0.5
#
# abalone9-18:
#   PVAL:             0.0009  TRUE
#   Mean synthOve AUC 0.8669
#   Mean baseline AUC 0.8044
#   Mean noOptimi AUC 0.5703
#
# cleveland-0_vs_4:
#   PVAL:             0.1057  FALSE
#   Mean synthOve AUC 0.9426
#   Mean baseline AUC 0.9257
#   Mean noOptimi AUC 0.682
#
# ecoli-0-1-4-7_vs_2-3-5-6:
#   PVAL:             0.0049  TRUE
#   Mean synthOve AUC 0.9365
#   Mean baseline AUC 0.9036
#   Mean noOptimi AUC 0.8704
#
# ecoli-0-1-4-7_vs_5-6:
#   PVAL:             0.0051  TRUE
#   Mean synthOve AUC 0.9395
#   Mean baseline AUC 0.9071
#   Mean noOptimi AUC 0.8773
#
# ecoli-0-2-6-7_vs_3-5:
#   PVAL:             0.0005  TRUE
#   Mean synthOve AUC 0.9183
#   Mean baseline AUC 0.856
#   Mean noOptimi AUC 0.7467
#
# ecoli-0-4-6_vs_5:
#   PVAL:             0.0038  TRUE
#   Mean synthOve AUC 0.9476
#   Mean baseline AUC 0.9144
#   Mean noOptimi AUC 0.8743
#
# ecoli-0-6-7_vs_3-5:
#   PVAL:             0.0051  TRUE
#   Mean synthOve AUC 0.9388
#   Mean baseline AUC 0.899
#   Mean noOptimi AUC 0.7835
#
# ecoli4:
#   PVAL:             0.0062  TRUE
#   Mean synthOve AUC 0.9717
#   Mean baseline AUC 0.9591
#   Mean noOptimi AUC 0.8889
#
# glass-0-6_vs_5:
#   PVAL:             0.0038  TRUE
#   Mean synthOve AUC 0.9405
#   Mean baseline AUC 0.8863
#   Mean noOptimi AUC 0.7117
#
# winequality-red-4:
#   PVAL:             0.0255  TRUE
#   Mean synthOve AUC 0.6903
#   Mean baseline AUC 0.6503
#   Mean noOptimi AUC 0.5058
#
# winequality-red-8_vs_6-7:
#   PVAL:             0.0002  TRUE
#   Mean synthOve AUC 0.8451
#   Mean baseline AUC 0.741
#   Mean noOptimi AUC 0.5
#
# winequality-white-9_vs_4:
#   PVAL:             0.0007  TRUE
#   Mean synthOve AUC 0.9383
#   Mean baseline AUC 0.8809
#   Mean noOptimi AUC 0.5803
#
# wisconsin:
#   PVAL:             0.0063  TRUE
#   Mean synthOve AUC 0.9829
#   Mean baseline AUC 0.9758
#   Mean noOptimi AUC 0.9609
#
# yeast-0-2-5-7-9_vs_3-6-8:
#   PVAL:             0.1022  FALSE
#   Mean synthOve AUC 0.9333
#   Mean baseline AUC 0.923
#   Mean noOptimi AUC 0.8825
#
# yeast-2_vs_4:
#   PVAL:             0.0042  TRUE
#   Mean synthOve AUC 0.9401
#   Mean baseline AUC 0.9085
#   Mean noOptimi AUC 0.8001

# %%
records = []

for dataset in splits.columns:

	synthetic_optimized_auc = []
	nsga_2 = []
	smote = []
	adasyn = []
	borderline_smote = []
	smote_tomek = []
	smote_enn = []

	irs = []

	print(dataset)
	for data_key in splits[dataset]:
		x_train = data_mapper[data_key]['x_train'] 
		y_train = data_mapper[data_key]['y_train']
		x_validation = data_mapper[data_key]['x_validation'] 
		y_validation = data_mapper[data_key]['y_validation']
		x_test = data_mapper[data_key]['x_test'] 
		y_test = data_mapper[data_key]['y_test']

		counts = pd.DataFrame(y_train).value_counts()
		irs.append(counts.max()/counts.min() )
		max_validation_AUC = []
		result_by_idx = []

		if data_key not in data_key_iters: continue
		
		for generation_file in data_key_iters[data_key]:
			with open(f"results/{generation_file}", "rb") as fh:
				result_dict = pickle.load(fh)

			validation_auc = []
			test_auc = []

			for instance in result_dict['Result'].X:
				if np.sum(instance) >= AUC_Optimizer.n_neighbours:
					model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
					model.fit(result_dict['Base x_train'][instance], result_dict['Base y_train'][instance] )
					y_pred = model.predict(x_validation)
					validation_auc.append(roc_auc_score(y_validation, y_pred))
					# y_pred = model.predict(x_test)
					# test_auc.append(roc_auc_score(y_test, y_pred))
				else:
					validation_auc.append(0)
					# test_auc.append(0)

			# validation_idx = np.argmax(validation_auc)
			max_validation_AUC.append(np.max(validation_auc))
			result_by_idx.append(result_dict)
			# test_idx = np.argmax(test_auc)	
			# validation_ideal_x_train = result_dict['Base x_train'][result_dict['Result'].X[validation_idx]]
			# validation_ideal_y_train = result_dict['Base y_train'][result_dict['Result'].X[validation_idx]]
			# test_ideal_x_train = result_dict['Base x_train'][result_dict['Result'].X[test_idx]]
			# test_ideal_y_train = result_dict['Base y_train'][result_dict['Result'].X[test_idx]]

		best_generation_idx = np.argmax(max_validation_AUC)
		# synthetic_optimized_auc.append(np.max(max_validation_AUC))
		best_result = result_by_idx[best_generation_idx]
		
		# test_auc = []
		validation_auc = []
		for instance in best_result['Result'].X:
			if np.sum(instance) > AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(best_result['Base x_train'][instance], best_result['Base y_train'][instance] )
				# y_pred = model.predict(x_test)
				# test_auc.append(roc_auc_score(y_test, y_pred))
				y_pred = model.predict(x_validation)
				validation_auc.append(roc_auc_score(y_validation, y_pred))
			else:
				validation_auc.append(0)
		# test_idx = np.argmax(test_auc)
		validation_idx = np.argmax(validation_auc)
		
		# test_ideal_x_train = best_result['Base x_train'][best_result['Result'].X[test_idx]]
		# test_ideal_y_train = best_result['Base y_train'][best_result['Result'].X[test_idx]]
		validation_ideal_x_train = best_result['Base x_train'][best_result['Result'].X[validation_idx]]
		validation_ideal_y_train = best_result['Base y_train'][best_result['Result'].X[validation_idx]]

		model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		model.fit(validation_ideal_x_train, validation_ideal_y_train)
		y_pred = model.predict(x_test)
		synthetic_optimized_auc.append(roc_auc_score(y_test, y_pred))

		# model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		# model.fit(test_ideal_x_train, test_ideal_y_train)
		# y_pred = model.predict(x_test)
		# synthetic_optimized_auc.append(roc_auc_score(y_test, y_pred))

		#########################################
		#
		##########################################

		competitor_results = competitor[data_key]
		smote.append(competitor_results['SMOTE'])
		adasyn.append(competitor_results['ADASYN'])
		borderline_smote.append(competitor_results['Borderline SMOTE'])
		smote_tomek.append(competitor_results['SMOTE Tomek'])
		smote_enn.append(competitor_results['SMOTE EENN'])

		#########################################
		#
		##########################################
		
		# problem = AUC_Filter(
		# 	x_train, y_train, 
		# 	x_validation, y_validation,
		# 	X_test=x_test, Y_test=y_test,
		# )
		# algorithm = NSGA2(pop_size=AUC_Optimizer.population_size, sampling=DiverseCustomSampling(), crossover=HUX(), mutation=BitflipMutation(), eliminate_duplicates=True)
		# result = minimize(problem, algorithm, ('n_gen', AUC_Optimizer.population_size), save_history=False)
		# baseline_validation_auc = []
		# for instance in result.X:
		# 	if np.sum(instance) > AUC_Optimizer.n_neighbours:
		# 		model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		# 		model.fit(x_train[instance], y_train[instance] )
		# 		y_pred = model.predict(x_validation)
		# 		baseline_validation_auc.append(roc_auc_score(y_validation, y_pred))
		# 	else:
		# 		baseline_validation_auc.append(0)

		# best_wrt_validation = np.argmax(baseline_validation_auc)

		# if np.sum(result.X[best_wrt_validation]) > AUC_Optimizer.n_neighbours:
		# 	model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		# 	model.fit(x_train[result.X[best_wrt_validation]], y_train[result.X[best_wrt_validation]])
		# 	y_pred = model.predict(x_test)
		# 	nsga_2.append(roc_auc_score(y_test, y_pred))
		# else:
		# 	nsga_2.append(0)

	smote_wx = ranksums(smote, synthetic_optimized_auc).pvalue
	adasyn_wx = ranksums(adasyn, synthetic_optimized_auc).pvalue
	borderline_wx = ranksums(borderline_smote, synthetic_optimized_auc).pvalue
	tomek_wx = ranksums(smote_tomek, synthetic_optimized_auc).pvalue
	enn_wx = ranksums(smote_enn, synthetic_optimized_auc).pvalue
	nsga_wx = ranksums(nsga_2, synthetic_optimized_auc).pvalue

	me_auc = np.mean(synthetic_optimized_auc)
	smote_auc = np.mean(smote)
	adasyn_auc = np.mean(adasyn)
	borderline_auc = np.mean(borderline_smote)
	tomek_auc = np.mean(smote_tomek)
	enn_auc = np.mean(smote_enn)
	nsga_auc = np.mean(nsga_2)
	
	rankings = [me_auc, smote_auc, adasyn_auc, borderline_auc, tomek_auc, enn_auc, nsga_auc]
	ranking_titles = ['cVAE', 'SMOTE', 'ADASYN', 'BORDERLINE', 'TOMEK', 'ENN', 'NSGA-2']

	
	sorted_titles = pd.DataFrame(ranking_titles).iloc[np.argsort(rankings)]

	records.append({
		"IR": round(np.mean(irs), 2),
		"Dataset": dataset,
		"ME VS SMOTE": smote_wx,
		"ME VS ADASYN": adasyn_wx,
		"ME VS Borderline Smote": borderline_wx,
		"ME VS SMOTE Tomek": tomek_wx,
		"ME VS SMOTE ENN": enn_wx,
		"ME VS NSGA": nsga_wx,
		"cVAE": me_auc,
		"SMOTE": smote_auc,
		"ADASYN": adasyn_auc,
		"BORDERLINE": borderline_auc,
		"TOMEK": tomek_auc,
		"ENN": enn_auc,
		"NSGA-2": nsga_auc,
		"Ranked AUCs": np.sort(rankings),
		"Ranked titles": sorted_titles,
	})

	print(records[-1])
tt = pd.DataFrame.from_records(records)
# tt.head()
tt.to_excel('NEWEST.xlsx',index=False)
# Out:
# abalone-17_vs_7-8-9-10
# {'IR': np.float64(39.31), 'Dataset': 'abalone-17_vs_7-8-9-10', 'ME VS SMOTE': np.float64(3.564292259657079e-10), 'ME VS ADASYN': np.float64(7.981384840368783e-10), 'ME VS Borderline Smote': np.float64(5.138983899513966e-09), 'ME VS SMOTE Tomek': np.float64(5.109952508030462e-10), 'ME VS SMOTE ENN': np.float64(1.566933968351836e-10), 'ME VS NSGA': np.float64(0.06311624676030969), 'cVAE': np.float64(0.6361063950198076), 'SMOTE': np.float64(0.7726210688010348), 'ADASYN': np.float64(0.7725563909774436), 'BORDERLINE': np.float64(0.7638289271566013), 'TOMEK': np.float64(0.7796466973886327), 'ENN': np.float64(0.8092246745896999), 'NSGA-2': np.float64(0.6039776861508611), 'Ranked AUCs': array([0.60397769, 0.6361064 , 0.76382893, 0.77255639, 0.77262107,
#        0.7796467 , 0.80922467]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 3  BORDERLINE
# 2      ADASYN
# 1       SMOTE
# 4       TOMEK
# 5         ENN}
# abalone-20_vs_8-9-10
# {'IR': np.float64(72.69), 'Dataset': 'abalone-20_vs_8-9-10', 'ME VS SMOTE': np.float64(3.940456570403729e-05), 'ME VS ADASYN': np.float64(6.192462567368025e-05), 'ME VS Borderline Smote': np.float64(0.0520351123187207), 'ME VS SMOTE Tomek': np.float64(2.2587086639771772e-05), 'ME VS SMOTE ENN': np.float64(4.4840557334827095e-07), 'ME VS NSGA': np.float64(0.026597453664145305), 'cVAE': np.float64(0.6611458162526547), 'SMOTE': np.float64(0.7814850683284954), 'ADASYN': np.float64(0.7781487903067555), 'BORDERLINE': np.float64(0.7271482395692475), 'TOMEK': np.float64(0.7871685962983151), 'ENN': np.float64(0.8174738421012913), 'NSGA-2': np.float64(0.579852696912947), 'Ranked AUCs': array([0.5798527 , 0.66114582, 0.72714824, 0.77814879, 0.78148507,
#        0.7871686 , 0.81747384]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 3  BORDERLINE
# 2      ADASYN
# 1       SMOTE
# 4       TOMEK
# 5         ENN}
# abalone-21_vs_8
# {'IR': np.float64(40.43), 'Dataset': 'abalone-21_vs_8', 'ME VS SMOTE': np.float64(0.4902884559304884), 'ME VS ADASYN': np.float64(0.3601353126708602), 'ME VS Borderline Smote': np.float64(0.3243784580558534), 'ME VS SMOTE Tomek': np.float64(0.5263838033664119), 'ME VS SMOTE ENN': np.float64(0.4304627009065408), 'ME VS NSGA': np.float64(0.35645212914426705), 'cVAE': np.float64(0.840186278964107), 'SMOTE': np.float64(0.8468877782825989), 'ADASYN': np.float64(0.8430258973194003), 'BORDERLINE': np.float64(0.8026275935180976), 'TOMEK': np.float64(0.8471149477510224), 'ENN': np.float64(0.8439345751930938), 'NSGA-2': np.float64(0.7720354384370739), 'Ranked AUCs': array([0.77203544, 0.80262759, 0.84018628, 0.8430259 , 0.84393458,
#        0.84688778, 0.84711495]), 'Ranked titles':             0
# 6      NSGA-2
# 3  BORDERLINE
# 0        cVAE
# 2      ADASYN
# 5         ENN
# 1       SMOTE
# 4       TOMEK}
# abalone-3_vs_11
# {'IR': np.float64(33.12), 'Dataset': 'abalone-3_vs_11', 'ME VS SMOTE': np.float64(0.016377308341494895), 'ME VS ADASYN': np.float64(0.0004437381280828149), 'ME VS Borderline Smote': np.float64(0.016377308341494895), 'ME VS SMOTE Tomek': np.float64(0.02612056090330662), 'ME VS SMOTE ENN': np.float64(0.016377308341494895), 'ME VS NSGA': np.float64(0.9270867821633659), 'cVAE': np.float64(0.9978792540568415), 'SMOTE': np.float64(1.0), 'ADASYN': np.float64(0.3548387096774194), 'BORDERLINE': np.float64(1.0), 'TOMEK': np.float64(0.9998677948175568), 'ENN': np.float64(1.0), 'NSGA-2': np.float64(0.9981436644217279), 'Ranked AUCs': array([0.35483871, 0.99787925, 0.99814366, 0.99986779, 1.        ,
#        1.        , 1.        ]), 'Ranked titles':             0
# 2      ADASYN
# 0        cVAE
# 6      NSGA-2
# 4       TOMEK
# 3  BORDERLINE
# 1       SMOTE
# 5         ENN}
# abalone19
# {'IR': np.float64(129.44), 'Dataset': 'abalone19', 'ME VS SMOTE': np.float64(4.8849730594564623e-08), 'ME VS ADASYN': np.float64(4.8849730594564623e-08), 'ME VS Borderline Smote': np.float64(0.12663045794761718), 'ME VS SMOTE Tomek': np.float64(4.8849730594564623e-08), 'ME VS SMOTE ENN': np.float64(1.3353534438911939e-11), 'ME VS NSGA': np.float64(0.6422229979372139), 'cVAE': np.float64(0.4999532491818607), 'SMOTE': np.float64(0.6453560853981612), 'ADASYN': np.float64(0.6492792582203522), 'BORDERLINE': np.float64(0.5373870188561632), 'TOMEK': np.float64(0.6469670406732119), 'ENN': np.float64(0.688499298737728), 'NSGA-2': np.float64(0.49985974754558204), 'Ranked AUCs': array([0.49985975, 0.49995325, 0.53738702, 0.64535609, 0.64696704,
#        0.64927926, 0.6884993 ]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 3  BORDERLINE
# 1       SMOTE
# 4       TOMEK
# 2      ADASYN
# 5         ENN}
# abalone9-18
# {'IR': np.float64(16.38), 'Dataset': 'abalone9-18', 'ME VS SMOTE': np.float64(0.16552121244120443), 'ME VS ADASYN': np.float64(0.07043598122636725), 'ME VS Borderline Smote': np.float64(0.06212381707100627), 'ME VS SMOTE Tomek': np.float64(0.11811807615280061), 'ME VS SMOTE ENN': np.float64(0.1412340802023398), 'ME VS NSGA': np.float64(0.3789076077261103), 'cVAE': np.float64(0.7045532303990344), 'SMOTE': np.float64(0.7312479919769749), 'ADASYN': np.float64(0.7389198817045302), 'BORDERLINE': np.float64(0.7416968863865993), 'TOMEK': np.float64(0.7370325076014143), 'ENN': np.float64(0.7355711201841447), 'NSGA-2': np.float64(0.6907593983361843), 'Ranked AUCs': array([0.6907594 , 0.70455323, 0.73124799, 0.73557112, 0.73703251,
#        0.73891988, 0.74169689]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 1       SMOTE
# 5         ENN
# 4       TOMEK
# 2      ADASYN
# 3  BORDERLINE}
# cleveland-0_vs_4
# {'IR': np.float64(13.33), 'Dataset': 'cleveland-0_vs_4', 'ME VS SMOTE': np.float64(0.3943508085543097), 'ME VS ADASYN': np.float64(0.4101688349440915), 'ME VS Borderline Smote': np.float64(0.3789076077261103), 'ME VS SMOTE Tomek': np.float64(0.3982703098136746), 'ME VS SMOTE ENN': np.float64(0.34915728090379194), 'ME VS NSGA': np.float64(0.5781399961070663), 'cVAE': np.float64(0.8501344086021507), 'SMOTE': np.float64(0.9119623655913978), 'ADASYN': np.float64(0.9111559139784945), 'BORDERLINE': np.float64(0.9119623655913978), 'TOMEK': np.float64(0.9115591397849462), 'ENN': np.float64(0.9208333333333333), 'NSGA-2': np.float64(0.8173387096774193), 'Ranked AUCs': array([0.81733871, 0.85013441, 0.91115591, 0.91155914, 0.91196237,
#        0.91196237, 0.92083333]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 2      ADASYN
# 4       TOMEK
# 3  BORDERLINE
# 1       SMOTE
# 5         ENN}
# ecoli-0-1-4-7_vs_2-3-5-6
# {'IR': np.float64(10.66), 'Dataset': 'ecoli-0-1-4-7_vs_2-3-5-6', 'ME VS SMOTE': np.float64(0.02134381451518168), 'ME VS ADASYN': np.float64(0.02961965556269078), 'ME VS Borderline Smote': np.float64(0.008648268547596469), 'ME VS SMOTE Tomek': np.float64(0.047924241096568315), 'ME VS SMOTE ENN': np.float64(0.009012611246320093), 'ME VS NSGA': np.float64(0.281475406144562), 'cVAE': np.float64(0.8535474500033073), 'SMOTE': np.float64(0.9019910480012348), 'ADASYN': np.float64(0.8942297091702864), 'BORDERLINE': np.float64(0.9085038475955284), 'TOMEK': np.float64(0.8959219897250457), 'ENN': np.float64(0.9076260115097127), 'NSGA-2': np.float64(0.8370573611447973), 'Ranked AUCs': array([0.83705736, 0.85354745, 0.89422971, 0.89592199, 0.90199105,
#        0.90762601, 0.90850385]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 2      ADASYN
# 4       TOMEK
# 1       SMOTE
# 5         ENN
# 3  BORDERLINE}
# ecoli-0-1-4-7_vs_5-6
# {'IR': np.float64(11.77), 'Dataset': 'ecoli-0-1-4-7_vs_5-6', 'ME VS SMOTE': np.float64(0.005427220427676474), 'ME VS ADASYN': np.float64(0.0023036135947697147), 'ME VS Borderline Smote': np.float64(0.0007278768518158891), 'ME VS SMOTE Tomek': np.float64(0.0038140290724502026), 'ME VS SMOTE ENN': np.float64(0.005427220427676474), 'ME VS NSGA': np.float64(0.08333330621833963), 'cVAE': np.float64(0.8670576735092863), 'SMOTE': np.float64(0.9300027929060188), 'ADASYN': np.float64(0.9292347437508728), 'BORDERLINE': np.float64(0.9369850579528), 'TOMEK': np.float64(0.9320974724200533), 'ENN': np.float64(0.9285016059209608), 'NSGA-2': np.float64(0.8385351207931854), 'Ranked AUCs': array([0.83853512, 0.86705767, 0.92850161, 0.92923474, 0.93000279,
#        0.93209747, 0.93698506]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 5         ENN
# 2      ADASYN
# 1       SMOTE
# 4       TOMEK
# 3  BORDERLINE}
# ecoli-0-2-6-7_vs_3-5
# {'IR': np.float64(9.18), 'Dataset': 'ecoli-0-2-6-7_vs_3-5', 'ME VS SMOTE': np.float64(0.7728792619546765), 'ME VS ADASYN': np.float64(0.4727528154851811), 'ME VS Borderline Smote': np.float64(0.09808030337903566), 'ME VS SMOTE Tomek': np.float64(0.6625205835400574), 'ME VS SMOTE ENN': np.float64(0.5309893164049438), 'ME VS NSGA': np.float64(0.1393408153277279), 'cVAE': np.float64(0.81988614800759), 'SMOTE': np.float64(0.8212776723592663), 'ADASYN': np.float64(0.811821631878558), 'BORDERLINE': np.float64(0.7872549019607845), 'TOMEK': np.float64(0.8190449082858952), 'ENN': np.float64(0.8113725490196078), 'NSGA-2': np.float64(0.787552182163188), 'Ranked AUCs': array([0.7872549 , 0.78755218, 0.81137255, 0.81182163, 0.81904491,
#        0.81988615, 0.82127767]), 'Ranked titles':             0
# 3  BORDERLINE
# 6      NSGA-2
# 5         ENN
# 2      ADASYN
# 4       TOMEK
# 0        cVAE
# 1       SMOTE}
# ecoli-0-4-6_vs_5
# {'IR': np.float64(9.1), 'Dataset': 'ecoli-0-4-6_vs_5', 'ME VS SMOTE': np.float64(0.3209344518703803), 'ME VS ADASYN': np.float64(0.7407604510341188), 'ME VS Borderline Smote': np.float64(0.5402612686900601), 'ME VS SMOTE Tomek': np.float64(0.3527927765695593), 'ME VS SMOTE ENN': np.float64(0.7143330546484588), 'ME VS NSGA': np.float64(0.7621266287661469), 'cVAE': np.float64(0.8844319775596072), 'SMOTE': np.float64(0.9093969144460028), 'ADASYN': np.float64(0.8944600280504909), 'BORDERLINE': np.float64(0.8995792426367463), 'TOMEK': np.float64(0.908695652173913), 'ENN': np.float64(0.8949509116409539), 'NSGA-2': np.float64(0.8773492286115007), 'Ranked AUCs': array([0.87734923, 0.88443198, 0.89446003, 0.89495091, 0.89957924,
#        0.90869565, 0.90939691]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 2      ADASYN
# 5         ENN
# 3  BORDERLINE
# 4       TOMEK
# 1       SMOTE}
# ecoli-0-6-7_vs_3-5
# {'IR': np.float64(9.09), 'Dataset': 'ecoli-0-6-7_vs_3-5', 'ME VS SMOTE': np.float64(0.5543193695171094), 'ME VS ADASYN': np.float64(0.5685541077218975), 'ME VS Borderline Smote': np.float64(0.55904485935579), 'ME VS SMOTE Tomek': np.float64(0.6371893286375199), 'ME VS SMOTE ENN': np.float64(0.55904485935579), 'ME VS NSGA': np.float64(0.10393364909645059), 'cVAE': np.float64(0.8551612903225807), 'SMOTE': np.float64(0.8758064516129033), 'ADASYN': np.float64(0.8764516129032258), 'BORDERLINE': np.float64(0.8503225806451613), 'TOMEK': np.float64(0.8725806451612903), 'ENN': np.float64(0.877741935483871), 'NSGA-2': np.float64(0.8161290322580647), 'Ranked AUCs': array([0.81612903, 0.85032258, 0.85516129, 0.87258065, 0.87580645,
#        0.87645161, 0.87774194]), 'Ranked titles':             0
# 6      NSGA-2
# 3  BORDERLINE
# 0        cVAE
# 4       TOMEK
# 1       SMOTE
# 2      ADASYN
# 5         ENN}
# ecoli4
# {'IR': np.float64(15.8), 'Dataset': 'ecoli4', 'ME VS SMOTE': np.float64(0.48147719086541874), 'ME VS ADASYN': np.float64(0.5309893164049438), 'ME VS Borderline Smote': np.float64(0.8492615317796655), 'ME VS SMOTE Tomek': np.float64(0.36384229865389917), 'ME VS SMOTE ENN': np.float64(0.36757305604734236), 'ME VS NSGA': np.float64(0.6986371885578309), 'cVAE': np.float64(0.9147407104940792), 'SMOTE': np.float64(0.9180073499387507), 'ADASYN': np.float64(0.9220089832584729), 'BORDERLINE': np.float64(0.9085340955492037), 'TOMEK': np.float64(0.9208248264597796), 'ENN': np.float64(0.9348713760718661), 'NSGA-2': np.float64(0.9141690485912618), 'Ranked AUCs': array([0.9085341 , 0.91416905, 0.91474071, 0.91800735, 0.92082483,
#        0.92200898, 0.93487138]), 'Ranked titles':             0
# 3  BORDERLINE
# 6      NSGA-2
# 0        cVAE
# 1       SMOTE
# 4       TOMEK
# 2      ADASYN
# 5         ENN}
# glass-0-6_vs_5
# {'IR': np.float64(11.19), 'Dataset': 'glass-0-6_vs_5', 'ME VS SMOTE': np.float64(1.1204692171302723e-05), 'ME VS ADASYN': np.float64(1.3725435887500173e-06), 'ME VS Borderline Smote': np.float64(0.01173332756595272), 'ME VS SMOTE Tomek': np.float64(1.1953382465006899e-05), 'ME VS SMOTE ENN': np.float64(1.4039664794230857e-05), 'ME VS NSGA': np.float64(0.16985778287018294), 'cVAE': np.float64(0.8385752688172043), 'SMOTE': np.float64(0.9685483870967743), 'ADASYN': np.float64(0.9846774193548388), 'BORDERLINE': np.float64(0.9120967741935485), 'TOMEK': np.float64(0.9691935483870967), 'ENN': np.float64(0.9685483870967743), 'NSGA-2': np.float64(0.7651881720430109), 'Ranked AUCs': array([0.76518817, 0.83857527, 0.91209677, 0.96854839, 0.96854839,
#        0.96919355, 0.98467742]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 3  BORDERLINE
# 1       SMOTE
# 5         ENN
# 4       TOMEK
# 2      ADASYN}
# winequality-red-4
# {'IR': np.float64(29.73), 'Dataset': 'winequality-red-4', 'ME VS SMOTE': np.float64(4.872323725511199e-05), 'ME VS ADASYN': np.float64(9.352489315000378e-05), 'ME VS Borderline Smote': np.float64(5.387499200998989e-07), 'ME VS SMOTE Tomek': np.float64(4.316976258922601e-05), 'ME VS SMOTE ENN': np.float64(7.324784140214903e-06), 'ME VS NSGA': np.float64(0.7143330546484588), 'cVAE': np.float64(0.5660479725446744), 'SMOTE': np.float64(0.6356056609380951), 'ADASYN': np.float64(0.6253043871246997), 'BORDERLINE': np.float64(0.6597440286545855), 'TOMEK': np.float64(0.6308260386093316), 'ENN': np.float64(0.6469979949674355), 'NSGA-2': np.float64(0.5761965601005671), 'Ranked AUCs': array([0.56604797, 0.57619656, 0.62530439, 0.63082604, 0.63560566,
#        0.64699799, 0.65974403]), 'Ranked titles':             0
# 0        cVAE
# 6      NSGA-2
# 2      ADASYN
# 4       TOMEK
# 1       SMOTE
# 5         ENN
# 3  BORDERLINE}
# winequality-red-8_vs_6-7
# {'IR': np.float64(46.44), 'Dataset': 'winequality-red-8_vs_6-7', 'ME VS SMOTE': np.float64(0.778272118060392), 'ME VS ADASYN': np.float64(0.8327479062272571), 'ME VS Borderline Smote': np.float64(0.38658214756817255), 'ME VS SMOTE Tomek': np.float64(0.5356151849321827), 'ME VS SMOTE ENN': np.float64(0.21799571167289444), 'ME VS NSGA': np.float64(0.003900388088353309), 'cVAE': np.float64(0.5552629741509199), 'SMOTE': np.float64(0.5630805385898764), 'ADASYN': np.float64(0.5606246187315798), 'BORDERLINE': np.float64(0.5383635040680881), 'TOMEK': np.float64(0.5645763970042408), 'ENN': np.float64(0.583938585466599), 'NSGA-2': np.float64(0.276537568260828), 'Ranked AUCs': array([0.27653757, 0.5383635 , 0.55526297, 0.56062462, 0.56308054,
#        0.5645764 , 0.58393859]), 'Ranked titles':             0
# 6      NSGA-2
# 3  BORDERLINE
# 0        cVAE
# 2      ADASYN
# 1       SMOTE
# 4       TOMEK
# 5         ENN}
# winequality-white-9_vs_4
# {'IR': np.float64(32.87), 'Dataset': 'winequality-white-9_vs_4', 'ME VS SMOTE': np.float64(1.3353534438911939e-11), 'ME VS ADASYN': np.float64(1.3353534438911939e-11), 'ME VS Borderline Smote': np.float64(1.3353534438911939e-11), 'ME VS SMOTE Tomek': np.float64(1.3353534438911939e-11), 'ME VS SMOTE ENN': np.float64(1.3353534438911939e-11), 'ME VS NSGA': np.float64(9.635760611976494e-09), 'cVAE': np.float64(0.7738591660110151), 'SMOTE': np.float64(0.0), 'ADASYN': np.float64(0.0), 'BORDERLINE': np.float64(0.0), 'TOMEK': np.float64(0.0), 'ENN': np.float64(0.0), 'NSGA-2': np.float64(0.16522423288749016), 'Ranked AUCs': array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.16522423, 0.77385917]), 'Ranked titles':             0
# 1       SMOTE
# 2      ADASYN
# 3  BORDERLINE
# 4       TOMEK
# 5         ENN
# 6      NSGA-2
# 0        cVAE}
# wisconsin
# {'IR': np.float64(1.87), 'Dataset': 'wisconsin', 'ME VS SMOTE': np.float64(0.04051764430573218), 'ME VS ADASYN': np.float64(0.0013606279588373501), 'ME VS Borderline Smote': np.float64(0.004974577173762842), 'ME VS SMOTE Tomek': np.float64(0.08979726370900999), 'ME VS SMOTE ENN': np.float64(0.2051296819306716), 'ME VS NSGA': np.float64(0.6024314042605527), 'cVAE': np.float64(0.9617625690206336), 'SMOTE': np.float64(0.9688825922696892), 'ADASYN': np.float64(0.9733362394652717), 'BORDERLINE': np.float64(0.9718904388259226), 'TOMEK': np.float64(0.9684466724789306), 'ENN': np.float64(0.9669718105201975), 'NSGA-2': np.float64(0.9573815751235106), 'Ranked AUCs': array([0.95738158, 0.96176257, 0.96697181, 0.96844667, 0.96888259,
#        0.97189044, 0.97333624]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 5         ENN
# 4       TOMEK
# 1       SMOTE
# 3  BORDERLINE
# 2      ADASYN}
# yeast-0-2-5-7-9_vs_3-6-8
# {'IR': np.float64(9.13), 'Dataset': 'yeast-0-2-5-7-9_vs_3-6-8', 'ME VS SMOTE': np.float64(0.25121479395536206), 'ME VS ADASYN': np.float64(0.24544580942293348), 'ME VS Borderline Smote': np.float64(0.7890896818203967), 'ME VS SMOTE Tomek': np.float64(0.22869857732638244), 'ME VS SMOTE ENN': np.float64(0.2425964293442916), 'ME VS NSGA': np.float64(0.5217987834446736), 'cVAE': np.float64(0.8941088611691344), 'SMOTE': np.float64(0.9044956756176686), 'ADASYN': np.float64(0.8879408713236357), 'BORDERLINE': np.float64(0.8971939910536092), 'TOMEK': np.float64(0.9024644829290439), 'ENN': np.float64(0.9023697361565063), 'NSGA-2': np.float64(0.8846904708906945), 'Ranked AUCs': array([0.88469047, 0.88794087, 0.89410886, 0.89719399, 0.90236974,
#        0.90246448, 0.90449568]), 'Ranked titles':             0
# 6      NSGA-2
# 2      ADASYN
# 0        cVAE
# 3  BORDERLINE
# 5         ENN
# 4       TOMEK
# 1       SMOTE}
# yeast-2_vs_4
# {'IR': np.float64(9.1), 'Dataset': 'yeast-2_vs_4', 'ME VS SMOTE': np.float64(0.5309893164049438), 'ME VS ADASYN': np.float64(0.22330127165331903), 'ME VS Borderline Smote': np.float64(0.6779091844442207), 'ME VS SMOTE Tomek': np.float64(0.4101688349440915), 'ME VS SMOTE ENN': np.float64(0.2369676414114673), 'ME VS NSGA': np.float64(0.3040740898177029), 'cVAE': np.float64(0.8580349713480728), 'SMOTE': np.float64(0.8622451181357211), 'ADASYN': np.float64(0.8687794130230171), 'BORDERLINE': np.float64(0.8599823537362832), 'TOMEK': np.float64(0.8653717496090665), 'ENN': np.float64(0.8693690685674533), 'NSGA-2': np.float64(0.8377990595273085), 'Ranked AUCs': array([0.83779906, 0.85803497, 0.85998235, 0.86224512, 0.86537175,
#        0.86877941, 0.86936907]), 'Ranked titles':             0
# 6      NSGA-2
# 0        cVAE
# 3  BORDERLINE
# 1       SMOTE
# 4       TOMEK
# 2      ADASYN
# 5         ENN}

# %%
records = []

for dataset in splits.columns:

	synthetic_optimized_auc = []
	
	smote = []
	adasyn = []
	borderline_smote = []
	smote_tomek = []
	smote_enn = []

	irs = []

	for data_key in splits[dataset]:
		x_train = data_mapper[data_key]['x_train'] 
		y_train = data_mapper[data_key]['y_train']
		x_validation = data_mapper[data_key]['x_validation'] 
		y_validation = data_mapper[data_key]['y_validation']
		x_test = data_mapper[data_key]['x_test'] 
		y_test = data_mapper[data_key]['y_test']

		counts = pd.DataFrame(y_train).value_counts()
		irs.append(counts.max()/counts.min() )
		max_validation_AUC = []
		result_by_idx = []

		# model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		# model.fit(x_train, y_train)
		# y_pred = model.predict(x_test)
		# baseline_auc.append(roc_auc_score(y_test, y_pred))
		# y_pred = model.predict(x_test)
		
		if data_key not in data_key_iters: continue
		
		for generation_file in data_key_iters[data_key]:
			with open(f"results/{generation_file}", "rb") as fh:
				result_dict = pickle.load(fh)

			validation_auc = []
			test_auc = []

			# for individual in result_dict['Result'].pop: >> No NDS
			# 	instance = individual.X
			for instance in result_dict['Result'].X:
				if np.sum(instance) >= AUC_Optimizer.n_neighbours:
					model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
					model.fit(result_dict['Base x_train'][instance], result_dict['Base y_train'][instance] )
					y_pred = model.predict(x_validation)
					validation_auc.append(roc_auc_score(y_validation, y_pred))
					# y_pred = model.predict(x_test)
					# test_auc.append(roc_auc_score(y_test, y_pred))
				else:
					validation_auc.append(0)
					# test_auc.append(0)

			# validation_idx = np.argmax(validation_auc)
			max_validation_AUC.append(np.max(validation_auc))
			result_by_idx.append(result_dict)
			# test_idx = np.argmax(test_auc)	
			# validation_ideal_x_train = result_dict['Base x_train'][result_dict['Result'].X[validation_idx]]
			# validation_ideal_y_train = result_dict['Base y_train'][result_dict['Result'].X[validation_idx]]
			# test_ideal_x_train = result_dict['Base x_train'][result_dict['Result'].X[test_idx]]
			# test_ideal_y_train = result_dict['Base y_train'][result_dict['Result'].X[test_idx]]

		best_generation_idx = np.argmax(max_validation_AUC)
		# synthetic_optimized_auc.append(np.max(max_validation_AUC))
		best_result = result_by_idx[best_generation_idx]
		
		test_auc = []
		for instance in best_result['Result'].X:
			if np.sum(instance) >= AUC_Optimizer.n_neighbours:
				model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
				model.fit(best_result['Base x_train'][instance], best_result['Base y_train'][instance] )
				y_pred = model.predict(x_test)
				test_auc.append(roc_auc_score(y_test, y_pred))
			else:
				test_auc.append(0)
		test_idx = np.argmax(test_auc)

		test_ideal_x_train = best_result['Base x_train'][best_result['Result'].X[test_idx]]
		test_ideal_y_train = best_result['Base y_train'][best_result['Result'].X[test_idx]]

		model = KNeighborsClassifier(n_neighbors=AUC_Optimizer.n_neighbours)
		model.fit(test_ideal_x_train, test_ideal_y_train)
		y_pred = model.predict(x_test)
		synthetic_optimized_auc.append(roc_auc_score(y_test, y_pred))

		#########################################
		#
		##########################################

		competitor_results = competitor[data_key]
		smote.append(competitor_results['SMOTE'])
		adasyn.append(competitor_results['ADASYN'])
		borderline_smote.append(competitor_results['Borderline SMOTE'])
		smote_tomek.append(competitor_results['SMOTE Tomek'])
		smote_enn.append(competitor_results['SMOTE EENN'])
	
	smote_wx = ranksums(smote, synthetic_optimized_auc).pvalue
	adasyn_wx = ranksums(adasyn, synthetic_optimized_auc).pvalue
	borderline_wx = ranksums(borderline_smote, synthetic_optimized_auc).pvalue
	tomek_wx = ranksums(smote_tomek, synthetic_optimized_auc).pvalue
	enn_wx = ranksums(smote_enn, synthetic_optimized_auc).pvalue

	me_auc = np.mean(synthetic_optimized_auc)
	smote_auc = np.mean(smote)
	adasyn_auc = np.mean(adasyn)
	borderline_auc = np.mean(borderline_smote)
	tomek_auc = np.mean(smote_tomek)
	enn_auc = np.mean(smote_enn)
	
	rankings = [me_auc, smote_auc, adasyn_auc, borderline_auc, tomek_auc, enn_auc]
	ranking_titles = ['cVAE', 'SMOTE', 'ADASYN', 'BORDERLINE', 'TOMEK', 'ENN']

	
	sorted_titles = pd.DataFrame(ranking_titles).iloc[np.argsort(rankings)]

	records.append({
		"IR": round(np.mean(irs), 2),
		"Dataset": dataset,
		"ME VS SMOTE": smote_wx,
		"ME VS ADASYN": adasyn_wx,
		"ME VS Borderline Smote": borderline_wx,
		"ME VS SMOTE Tomek": tomek_wx,
		"ME VS SMOTE ENN": enn_wx,
		"cVAE": me_auc,
		"SMOTE": smote_auc,
		"ADASYN": adasyn_auc,
		"BORDERLINE": borderline_auc,
		"TOMEK": tomek_auc,
		"ENN": enn_auc,
		"Ranked AUCs": np.sort(rankings),
		"Ranked titles": sorted_titles,
	})

tt = pd.DataFrame.from_records(records)
tt.head()
